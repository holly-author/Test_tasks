# %%
import random
import keyboard

class Play():
    def low_damage():
        damage = random.randint(18,26)
        return damage
    
    def heavy_damage():
        damage = random.randint(10,36)
        return damage
    
    def heal():
        heal=random.randint(18,26)
        return heal

# %%
class Player(Play):
    health=100
    name = 'Player 1'

class Computer(Play):
    health=100
    name = 'Player 2'

# %%
# Вывод уровеня здоровья каждого игрока
def health_state():
    print('{} health: {}'.format(player_1.name, player_1.health))
    print('{} health: {}'.format(player_2.name, player_2.health))

# %%
# Функция проверяет завершилась ли игра, если уровень здоровья одного из игроков упал ниже нуля.
def game_over():
    if curr_player.health <= 0: 
        print('{} win. Game over'.format(next_player.name))
        return False 
    elif next_player.health <= 0:
        print('{} win. Game over'.format(curr_player.name))
        return False 
    else:
        return True

# %%
# Действие вибирается случаныйным образом из 3-х возможных, для каждого присваивается свой номер.
# Если уровень здоровья компьютера ниже 35, выполняется выбор из 2-х вариантов.
    
def action():
    if player_2.health < 35:
        action = random.choice([1,3])
    else:
        action = random.choice([1,2,3])
        
    # Для каждого действия вызывается соответствующая функция из класса Play        
    if action == 1:
        damage_level = next_player.low_damage()
        next_player.health -= damage_level
        print('{} used low damage -{}'.format(curr_player.name,damage_level))
        
    elif action == 2:
        damage_level = next_player.heavy_damage()
        next_player.health-= damage_level
        print('{} used heavy damage -{}'.format(curr_player.name,damage_level))
        
    else:
        heal_level = curr_player.heal()
        curr_player.health+=heal_level
        print('{} healed himself +{}'.format(curr_player.name,heal_level))
        
    health_state()

# %%
player_1 = Player
player_2 = Computer

# %%
# Выбор первого игрока происходит рандомно, 1 - для игрока, 2 - для компьютера.
# Curr_player хранит текущего игрока, а next_player - чей ход будет следующим.

curr_player = random.choice([1,2])
if curr_player == 1:
    curr_player = player_1
    next_player = player_2
    print ('>> You are {}! To start press space'.format(player_1.name))
    # Все дейтсвия игрока происходят по клавише space.
    keyboard.wait('space')
else: 
    curr_player = player_2
    next_player = player_1
    print('>> {} started'.format(player_2.name))

# Тело игры. Игра продолжается, пока функция game_over не вернет False.    
game = game_over()
while game:
    action()
    # Текущий игрок становится следующим, а следующий текущим.
    if curr_player == player_1:
        curr_player = player_2
        next_player = player_1
    else:
        curr_player = player_1
        next_player = player_2
        print('--------------------------------------------------------')
        print('>> Your turn. Press space to attack enemy or heal yourself')
        keyboard.wait('space')
    print('--------------------------------------------------------')
    game = game_over()
# Out:
# >> You are Player 1! To start press space
# Player 1 used heavy damage -14
# Player 1 health: 100
# Player 2 health: 86
# --------------------------------------------------------
# Player 2 used low damage -22
# Player 1 health: 78
# Player 2 health: 86
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used heavy damage -32
# Player 1 health: 78
# Player 2 health: 54
# --------------------------------------------------------
# Player 2 healed himself +22
# Player 1 health: 78
# Player 2 health: 76
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used low damage -25
# Player 1 health: 78
# Player 2 health: 51
# --------------------------------------------------------
# Player 2 used heavy damage -23
# Player 1 health: 55
# Player 2 health: 51
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used low damage -20
# Player 1 health: 55
# Player 2 health: 31
# --------------------------------------------------------
# Player 2 used low damage -26
# Player 1 health: 29
# Player 2 health: 31
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used low damage -21
# Player 1 health: 29
# Player 2 health: 10
# --------------------------------------------------------
# Player 2 healed himself +22
# Player 1 health: 29
# Player 2 health: 32
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 healed himself +25
# Player 1 health: 54
# Player 2 health: 32
# --------------------------------------------------------
# Player 2 healed himself +23
# Player 1 health: 54
# Player 2 health: 55
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used low damage -24
# Player 1 health: 54
# Player 2 health: 31
# --------------------------------------------------------
# Player 2 healed himself +21
# Player 1 health: 54
# Player 2 health: 52
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used low damage -26
# Player 1 health: 54
# Player 2 health: 26
# --------------------------------------------------------
# Player 2 healed himself +24
# Player 1 health: 54
# Player 2 health: 50
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used low damage -22
# Player 1 health: 54
# Player 2 health: 28
# --------------------------------------------------------
# Player 2 used low damage -24
# Player 1 health: 30
# Player 2 health: 28
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used low damage -24
# Player 1 health: 30
# Player 2 health: 4
# --------------------------------------------------------
# Player 2 used low damage -22
# Player 1 health: 8
# Player 2 health: 4
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 healed himself +18
# Player 1 health: 26
# Player 2 health: 4
# --------------------------------------------------------
# Player 2 used low damage -24
# Player 1 health: 2
# Player 2 health: 4
# --------------------------------------------------------
# >> Your turn. Press space to attack enemy or heal yourself
# --------------------------------------------------------
# Player 1 used low damage -22
# Player 1 health: 2
# Player 2 health: -18
# --------------------------------------------------------
# Player 1 win. Game over
